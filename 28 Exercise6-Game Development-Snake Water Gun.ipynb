# %% [markdown]
# ### <font color="brown"> This is the first ever game I am developing using Python. I know it's a silly game but everything's silly when you start something. </font>
# ## <font color="Grey"> Snake Water Gun</font>
# It's a multiplayer game where
# 1. If someone says Snake and the other person says water, snake drinks the water and snake wins.
# 2. If someone says water and the other says gun, the gun drowns in the water and water wins.
# 3. If someone says gun and the other says snake, the gun kills the snake and gun wins-- Par naagin intekaam legi bhai.
#
# So this game will be between the user and the computer. It will be played 10 times and whoever with most number of wins, wins the game.

# %%
import random


print("*************************************                **********************************************")
print("*************************************SNAKE-WATER-GAME**********************************************")
print("*************************************                **********************************************")
print("*********************************** WELCOME TO THE GAME********************************************")

def func_game():
    options=["Snake", "Water", "Gun"]
    n=0
    global your_score
    global computer_score
    while(n<=10):
        computer=random.choice(options)
        print("The computer has made it's choice. Now it's your turn")
        b=input("Snake Water or Gun? :")
        you=b.capitalize()
        if(computer=="Snake"):
            if(you=="Water"):
                print("Hard luck")
                computer_score+=1
            elif(you=="Gun"):
                print("Congratulations")
                your_score+=1
            else:
                print("Both scored nothing")
        elif(computer=="Water"):
            if (you == "Gun"):
                print("Hard luck")
                computer_score += 1
            elif (you == "Snake"):
                print("Congratulations")
                your_score += 1
            else:
                print("Both scored nothing")
        else:
            if (you == "Snake"):
                print("Hard luck")
                computer_score += 1
            elif (you == "Water"):
                print("Congratulations")
                your_score += 1
            else:
                print("Both scored nothing")
        n+=1



first_wish=input("Are you ready to play the game?(Y/N): ")
if (first_wish=="Y"):
    your_score = 0
    computer_score = 0
    func_game()
    if(your_score>computer_score):
        print("Congratulations!!! You have won this game:")
    elif(computer_score>your_score):
        print("Sorry!!! You didn't win. Better luck next time.")
    else:
        print("OH MY GOD. It's a draw")
    second_wish = input("Do Yoy want to play again?(Y/N): ")
    while (second_wish == "Y"):
        your_score = 0
        computer_score = 0
        func_game()
        if (your_score > computer_score):
            print("Congratulations!!! You have won this game:")
        elif (computer_score > your_score):
            print("Sorry!!! You didn't win. Better luck next time.")
        else:
            print("OH MY GOD. It's a draw")
        second_wish = print("Do Yoy want to play again?(Y/N): ")
else:
    print("Come back when you want!")

print("Bbye!Come back when you want!")
# Out:
# *************************************                **********************************************
# *************************************SNAKE-WATER-GAME**********************************************
# *************************************                **********************************************
# *********************************** WELCOME TO THE GAME********************************************
# Are you ready to play the game?(Y/N): Y
# The computer has made it's choice. Now it's your turn
# Snake Water or Gun? :snake
# Both scored nothing
# The computer has made it's choice. Now it's your turn
# Snake Water or Gun? :snake
# Hard luck
# The computer has made it's choice. Now it's your turn
# Snake Water or Gun? :snake
# Hard luck
# The computer has made it's choice. Now it's your turn
# Snake Water or Gun? :snake
# Hard luck
# The computer has made it's choice. Now it's your turn
# Snake Water or Gun? :snake
# Hard luck
# ...
